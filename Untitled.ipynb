# %%
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
# ========================== 1. 定义 VAE 网络 ========================== #
class VAE(nn.Module):
    def __init__(self, input_dim=10, latent_dim=2, output_dim=10):
        """
        变分自编码器 (VAE) 结构
        :param input_dim: 输入数据的维度，例如机器人状态的特征数
        :param inter_dim: 中间隐藏层的神经元数量
        :param latent_dim: 潜在空间的维度 (通常小于 input_dim)
        """
        super(VAE, self).__init__()

        # 编码器 (encoder)，用于提取特征并生成均值 (mu) 和方差 (logvar)
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 256),  # 输入层 -> 隐藏层
            nn.Tanh(),
            nn.Linear(256, 128),
            nn.Tanh(),
            nn.Linear(128, latent_dim * 2),  # 隐藏层 -> 输出层 (均值和方差)
        )

        # 解码器 (decoder)，用于从潜在空间重构输入
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 256),  # 潜在空间 -> 隐藏层
            nn.Tanh(),
            nn.Linear(256, 128),
            nn.Tanh(),
            nn.Linear(128, output_dim),  # 隐藏层 -> 重建输入
            nn.Sigmoid(),  # 使用 Sigmoid 限制输出范围在 [0,1]
        )

    def reparameterize(self, mu, logvar):
        """
        重新参数化 (Reparameterization Trick)，用于从高斯分布中采样
        :param mu: 均值
        :param logvar: 对数方差
        :return: 采样后的潜在变量 z
        """
        epsilon = torch.randn_like(mu)  # 生成与 mu 形状相同的标准正态分布随机变量
        return mu + epsilon * torch.exp(logvar / 2)  # 计算 z = μ + ε * σ

    def forward(self, x):
        """
        前向传播
        :param x: 输入数据 (batch_size, input_dim)
        :return: 重构的 x, 均值 mu, 对数方差 logvar
        """
        batch = x.size(0)  # 获取 batch 大小
        h = self.encoder(x)  # 通过编码器提取特征
        mu, logvar = h.chunk(2, dim=1)  # 将输出拆分为均值和对数方差
        z = self.reparameterize(mu, logvar)  # 重新参数化采样
        recon_x = self.decoder(z)  # 通过解码器重建输入
        return recon_x, mu, logvar

# %%
# ========================== 2. 自定义数据集 ========================== #
class RLObservationDataset(Dataset):
    """
    强化学习环境观测数据集
    用于存储从 RL 环境收集的观测值
    """

    def __init__(self, file_path):
        import pandas as pd
        self.data = pd.read_csv(file_path).values  # 读取 CSV 并转换为 NumPy 数组
        # self.data = np.load(file_path)  # 载入 NumPy 数据文件
        self.data = self.normalize_data(self.data)  # 归一化数据
        self.data = torch.tensor(self.data, dtype=torch.float32)  # 转换为 PyTorch Tensor

    def normalize_data(self, data):
        """
        归一化数据到 [0,1] 之间，避免 BCE 损失函数报错。
        :param data: numpy.ndarray, 原始数据
        :return: numpy.ndarray, 归一化后的数据
        """
        # min_val = data.min(axis=0)  # 计算每列的最小值
        # max_val = data.max(axis=0)  # 计算每列的最大值

        # # **避免除以 0 的情况**
        # range_val = max_val - min_val
        # range_val[range_val == 0] = 1  # 如果最大值和最小值相同，则防止除以 0

        # return (data - min_val) / range_val  # 归一化到 [0,1]
        return 1 / (1 + np.exp(-data))

    def __len__(self):
        return len(self.data)  # 返回数据集的大小

    def __getitem__(self, idx):
        return self.data[idx], 0  # 返回 (数据, 标签)，标签在 VAE 里不用

# %%
# ========================== 3. 训练参数 ========================== #
epochs = 100  # 训练轮数
batch_size = 1024*8  # 每个批次的样本数量
input_dim = 84  # 输入数据的维度 (你的环境观测值的大小)
output_dim = 42
latent_dim = 32  # 潜在空间的维度

# 加载自定义数据集
from torch.utils.data import random_split

# 设定训练集和测试集比例
train_ratio = 0.8  # 80% 作为训练集，20% 作为测试集
dataset = RLObservationDataset("log.csv")

# 计算训练集和测试集的大小
train_size = int(train_ratio * len(dataset))
test_size = len(dataset) - train_size

# 随机划分数据
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"训练集大小: {len(train_dataset)}, 测试集大小: {len(test_dataset)}")

# 设备选择 (GPU 优先)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# 初始化模型和优化器
model = VAE(input_dim, latent_dim, output_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-5)

# 损失函数
kl_loss = lambda mu, logvar: -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
recon_loss = lambda recon_x, x: F.binary_cross_entropy(recon_x, x, reduction='sum')

# 记录损失值
train_losses = []
# Out:
# 训练集大小: 191999, 测试集大小: 48000

# %%
# ========================== 4. 训练 VAE ========================== #
best_loss = float('inf')  # 记录最佳损失

for epoch in range(epochs):
    # print(f"Epoch {epoch}")
    model.train()
    train_loss = 0.

    for idx, (x, _) in enumerate(train_loader):
        batch = x.size(0)
        x = x.to(device)
        _x = x[:, :42 * 2]
        real_x = x[:, -42:]
        recon_x, mu, logvar = model(_x)

        # 计算损失：重构损失 + KL 散度
        recon = recon_loss(recon_x, real_x)
        kl = kl_loss(mu, logvar)
        loss = recon + kl

        train_loss += loss.item()
        loss = loss / batch  # 归一化损失

        # 反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if idx % 100 == 0:
            print(f"Epoch {epoch} 训练损失 {loss:.3f} \t 重构损失 {recon / batch:.3f} \t KL {kl / batch:.3f} 在步骤 {idx}")

    epoch_loss = train_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)

    # 记录并保存最优模型
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), "vae_model.pth")
        print(f"Epoch {epoch}: 发现更优模型，已保存。")
# Out:
# Epoch 0 训练损失 29.443 	 重构损失 29.181 	 KL 0.262 在步骤 0
# Epoch 0: 发现更优模型，已保存。
# Epoch 1 训练损失 29.341 	 重构损失 29.165 	 KL 0.176 在步骤 0
# Epoch 1: 发现更优模型，已保存。
# Epoch 2 训练损失 29.269 	 重构损失 29.151 	 KL 0.118 在步骤 0
# Epoch 2: 发现更优模型，已保存。
# Epoch 3 训练损失 29.219 	 重构损失 29.139 	 KL 0.080 在步骤 0
# Epoch 3: 发现更优模型，已保存。
# Epoch 4 训练损失 29.182 	 重构损失 29.127 	 KL 0.055 在步骤 0
# Epoch 4: 发现更优模型，已保存。
# Epoch 5 训练损失 29.155 	 重构损失 29.116 	 KL 0.038 在步骤 0
# Epoch 5: 发现更优模型，已保存。
# Epoch 6 训练损失 29.132 	 重构损失 29.105 	 KL 0.027 在步骤 0
# Epoch 6: 发现更优模型，已保存。
# Epoch 7 训练损失 29.118 	 重构损失 29.098 	 KL 0.020 在步骤 0
# Epoch 7: 发现更优模型，已保存。
# Epoch 8 训练损失 29.101 	 重构损失 29.085 	 KL 0.016 在步骤 0
# Epoch 8: 发现更优模型，已保存。
# Epoch 9 训练损失 29.089 	 重构损失 29.076 	 KL 0.013 在步骤 0
# Epoch 9: 发现更优模型，已保存。
# Epoch 10 训练损失 29.078 	 重构损失 29.066 	 KL 0.011 在步骤 0
# Epoch 10: 发现更优模型，已保存。
# Epoch 11 训练损失 29.069 	 重构损失 29.059 	 KL 0.010 在步骤 0
# Epoch 11: 发现更优模型，已保存。
# Epoch 12 训练损失 29.059 	 重构损失 29.050 	 KL 0.009 在步骤 0
# Epoch 12: 发现更优模型，已保存。
# Epoch 13 训练损失 29.052 	 重构损失 29.043 	 KL 0.009 在步骤 0
# Epoch 13: 发现更优模型，已保存。
# Epoch 14 训练损失 29.044 	 重构损失 29.035 	 KL 0.008 在步骤 0
# Epoch 14: 发现更优模型，已保存。
# Epoch 15 训练损失 29.038 	 重构损失 29.030 	 KL 0.008 在步骤 0
# Epoch 15: 发现更优模型，已保存。
# Epoch 16 训练损失 29.030 	 重构损失 29.022 	 KL 0.008 在步骤 0
# Epoch 16: 发现更优模型，已保存。
# Epoch 17 训练损失 29.024 	 重构损失 29.017 	 KL 0.008 在步骤 0
# Epoch 17: 发现更优模型，已保存。
# Epoch 18 训练损失 29.018 	 重构损失 29.010 	 KL 0.008 在步骤 0
# Epoch 18: 发现更优模型，已保存。
# Epoch 19 训练损失 29.015 	 重构损失 29.008 	 KL 0.008 在步骤 0
# Epoch 19: 发现更优模型，已保存。
# Epoch 20 训练损失 29.009 	 重构损失 29.002 	 KL 0.007 在步骤 0
# Epoch 20: 发现更优模型，已保存。
# Epoch 21 训练损失 29.006 	 重构损失 28.999 	 KL 0.007 在步骤 0
# Epoch 21: 发现更优模型，已保存。
# Epoch 22 训练损失 29.001 	 重构损失 28.994 	 KL 0.007 在步骤 0
# Epoch 22: 发现更优模型，已保存。
# Epoch 23 训练损失 28.999 	 重构损失 28.992 	 KL 0.007 在步骤 0
# Epoch 23: 发现更优模型，已保存。
# Epoch 24 训练损失 28.996 	 重构损失 28.989 	 KL 0.007 在步骤 0
# Epoch 24: 发现更优模型，已保存。
# Epoch 25 训练损失 28.994 	 重构损失 28.987 	 KL 0.007 在步骤 0
# Epoch 25: 发现更优模型，已保存。
# Epoch 26 训练损失 28.991 	 重构损失 28.985 	 KL 0.007 在步骤 0
# Epoch 26: 发现更优模型，已保存。
# Epoch 27 训练损失 28.989 	 重构损失 28.983 	 KL 0.007 在步骤 0
# Epoch 27: 发现更优模型，已保存。
# Epoch 28 训练损失 28.988 	 重构损失 28.982 	 KL 0.006 在步骤 0
# Epoch 28: 发现更优模型，已保存。
# Epoch 29 训练损失 28.987 	 重构损失 28.981 	 KL 0.006 在步骤 0
# Epoch 29: 发现更优模型，已保存。
# Epoch 30 训练损失 28.986 	 重构损失 28.980 	 KL 0.006 在步骤 0
# Epoch 30: 发现更优模型，已保存。
# Epoch 31 训练损失 28.984 	 重构损失 28.978 	 KL 0.006 在步骤 0
# Epoch 31: 发现更优模型，已保存。
# Epoch 32 训练损失 28.983 	 重构损失 28.977 	 KL 0.006 在步骤 0
# Epoch 32: 发现更优模型，已保存。
# Epoch 33 训练损失 28.983 	 重构损失 28.977 	 KL 0.006 在步骤 0
# Epoch 33: 发现更优模型，已保存。
# Epoch 34 训练损失 28.979 	 重构损失 28.974 	 KL 0.006 在步骤 0
# Epoch 34: 发现更优模型，已保存。
# Epoch 35 训练损失 28.980 	 重构损失 28.975 	 KL 0.006 在步骤 0
# Epoch 35: 发现更优模型，已保存。
# Epoch 36 训练损失 28.978 	 重构损失 28.973 	 KL 0.006 在步骤 0
# Epoch 36: 发现更优模型，已保存。
# Epoch 37 训练损失 28.980 	 重构损失 28.975 	 KL 0.006 在步骤 0
# Epoch 37: 发现更优模型，已保存。
# Epoch 38 训练损失 28.980 	 重构损失 28.975 	 KL 0.005 在步骤 0
# Epoch 38: 发现更优模型，已保存。
# Epoch 39 训练损失 28.977 	 重构损失 28.971 	 KL 0.005 在步骤 0
# Epoch 39: 发现更优模型，已保存。
# Epoch 40 训练损失 28.978 	 重构损失 28.972 	 KL 0.005 在步骤 0
# Epoch 40: 发现更优模型，已保存。
# Epoch 41 训练损失 28.976 	 重构损失 28.971 	 KL 0.005 在步骤 0
# Epoch 41: 发现更优模型，已保存。
# Epoch 42 训练损失 28.977 	 重构损失 28.972 	 KL 0.005 在步骤 0
# Epoch 42: 发现更优模型，已保存。
# Epoch 43 训练损失 28.976 	 重构损失 28.971 	 KL 0.005 在步骤 0
# Epoch 43: 发现更优模型，已保存。
# Epoch 44 训练损失 28.975 	 重构损失 28.970 	 KL 0.005 在步骤 0
# Epoch 44: 发现更优模型，已保存。
# Epoch 45 训练损失 28.976 	 重构损失 28.971 	 KL 0.005 在步骤 0
# Epoch 45: 发现更优模型，已保存。
# Epoch 46 训练损失 28.974 	 重构损失 28.970 	 KL 0.005 在步骤 0
# Epoch 46: 发现更优模型，已保存。
# Epoch 47 训练损失 28.976 	 重构损失 28.972 	 KL 0.005 在步骤 0
# Epoch 47: 发现更优模型，已保存。
# Epoch 48 训练损失 28.974 	 重构损失 28.969 	 KL 0.005 在步骤 0
# Epoch 48: 发现更优模型，已保存。
# Epoch 49 训练损失 28.975 	 重构损失 28.970 	 KL 0.005 在步骤 0
# Epoch 49: 发现更优模型，已保存。
# Epoch 50 训练损失 28.974 	 重构损失 28.969 	 KL 0.004 在步骤 0
# Epoch 50: 发现更优模型，已保存。
# Epoch 51 训练损失 28.974 	 重构损失 28.969 	 KL 0.004 在步骤 0
# Epoch 51: 发现更优模型，已保存。
# Epoch 52 训练损失 28.974 	 重构损失 28.969 	 KL 0.004 在步骤 0
# Epoch 52: 发现更优模型，已保存。
# Epoch 53 训练损失 28.972 	 重构损失 28.967 	 KL 0.004 在步骤 0
# Epoch 53: 发现更优模型，已保存。
# Epoch 54 训练损失 28.973 	 重构损失 28.969 	 KL 0.004 在步骤 0
# Epoch 54: 发现更优模型，已保存。
# Epoch 55 训练损失 28.972 	 重构损失 28.968 	 KL 0.004 在步骤 0
# Epoch 55: 发现更优模型，已保存。
# Epoch 56 训练损失 28.970 	 重构损失 28.966 	 KL 0.004 在步骤 0
# Epoch 56: 发现更优模型，已保存。
# Epoch 57 训练损失 28.971 	 重构损失 28.967 	 KL 0.004 在步骤 0
# Epoch 57: 发现更优模型，已保存。
# Epoch 58 训练损失 28.970 	 重构损失 28.966 	 KL 0.004 在步骤 0
# Epoch 58: 发现更优模型，已保存。
# Epoch 59 训练损失 28.972 	 重构损失 28.968 	 KL 0.004 在步骤 0
# Epoch 59: 发现更优模型，已保存。
# Epoch 60 训练损失 28.970 	 重构损失 28.967 	 KL 0.004 在步骤 0
# Epoch 60: 发现更优模型，已保存。
# Epoch 61 训练损失 28.970 	 重构损失 28.966 	 KL 0.004 在步骤 0
# Epoch 61: 发现更优模型，已保存。
# Epoch 62 训练损失 28.969 	 重构损失 28.965 	 KL 0.004 在步骤 0
# Epoch 62: 发现更优模型，已保存。
# Epoch 63 训练损失 28.971 	 重构损失 28.967 	 KL 0.004 在步骤 0
# Epoch 63: 发现更优模型，已保存。
# Epoch 64 训练损失 28.968 	 重构损失 28.964 	 KL 0.004 在步骤 0
# Epoch 64: 发现更优模型，已保存。
# Epoch 65 训练损失 28.970 	 重构损失 28.967 	 KL 0.003 在步骤 0
# Epoch 65: 发现更优模型，已保存。
# Epoch 66 训练损失 28.970 	 重构损失 28.966 	 KL 0.003 在步骤 0
# Epoch 66: 发现更优模型，已保存。
# Epoch 67 训练损失 28.969 	 重构损失 28.966 	 KL 0.003 在步骤 0
# Epoch 67: 发现更优模型，已保存。
# Epoch 68 训练损失 28.971 	 重构损失 28.967 	 KL 0.003 在步骤 0
# Epoch 68: 发现更优模型，已保存。
# Epoch 69 训练损失 28.970 	 重构损失 28.967 	 KL 0.003 在步骤 0
# Epoch 69: 发现更优模型，已保存。
# Epoch 70 训练损失 28.969 	 重构损失 28.966 	 KL 0.003 在步骤 0
# Epoch 70: 发现更优模型，已保存。
# Epoch 71 训练损失 28.967 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 71: 发现更优模型，已保存。
# Epoch 72 训练损失 28.968 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 73 训练损失 28.968 	 重构损失 28.965 	 KL 0.003 在步骤 0
# Epoch 73: 发现更优模型，已保存。
# Epoch 74 训练损失 28.968 	 重构损失 28.965 	 KL 0.003 在步骤 0
# Epoch 74: 发现更优模型，已保存。
# Epoch 75 训练损失 28.968 	 重构损失 28.965 	 KL 0.003 在步骤 0
# Epoch 75: 发现更优模型，已保存。
# Epoch 76 训练损失 28.968 	 重构损失 28.965 	 KL 0.003 在步骤 0
# Epoch 77 训练损失 28.969 	 重构损失 28.966 	 KL 0.003 在步骤 0
# Epoch 77: 发现更优模型，已保存。
# Epoch 78 训练损失 28.969 	 重构损失 28.966 	 KL 0.003 在步骤 0
# Epoch 78: 发现更优模型，已保存。
# Epoch 79 训练损失 28.967 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 79: 发现更优模型，已保存。
# Epoch 80 训练损失 28.967 	 重构损失 28.965 	 KL 0.003 在步骤 0
# Epoch 80: 发现更优模型，已保存。
# Epoch 81 训练损失 28.966 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 81: 发现更优模型，已保存。
# Epoch 82 训练损失 28.966 	 重构损失 28.963 	 KL 0.003 在步骤 0
# Epoch 82: 发现更优模型，已保存。
# Epoch 83 训练损失 28.967 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 83: 发现更优模型，已保存。
# Epoch 84 训练损失 28.967 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 84: 发现更优模型，已保存。
# Epoch 85 训练损失 28.966 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 85: 发现更优模型，已保存。
# Epoch 86 训练损失 28.967 	 重构损失 28.964 	 KL 0.003 在步骤 0
# Epoch 86: 发现更优模型，已保存。
# Epoch 87 训练损失 28.966 	 重构损失 28.964 	 KL 0.002 在步骤 0
# Epoch 87: 发现更优模型，已保存。
# Epoch 88 训练损失 28.967 	 重构损失 28.964 	 KL 0.002 在步骤 0
# Epoch 88: 发现更优模型，已保存。
# Epoch 89 训练损失 28.966 	 重构损失 28.963 	 KL 0.002 在步骤 0
# Epoch 89: 发现更优模型，已保存。
# Epoch 90 训练损失 28.966 	 重构损失 28.964 	 KL 0.002 在步骤 0
# Epoch 90: 发现更优模型，已保存。
# Epoch 91 训练损失 28.965 	 重构损失 28.963 	 KL 0.002 在步骤 0
# Epoch 92 训练损失 28.966 	 重构损失 28.963 	 KL 0.002 在步骤 0
# Epoch 92: 发现更优模型，已保存。
# Epoch 93 训练损失 28.965 	 重构损失 28.962 	 KL 0.002 在步骤 0
# Epoch 93: 发现更优模型，已保存。
# Epoch 94 训练损失 28.965 	 重构损失 28.962 	 KL 0.002 在步骤 0
# Epoch 94: 发现更优模型，已保存。
# Epoch 95 训练损失 28.965 	 重构损失 28.962 	 KL 0.002 在步骤 0
# Epoch 95: 发现更优模型，已保存。
# Epoch 96 训练损失 28.966 	 重构损失 28.964 	 KL 0.002 在步骤 0
# Epoch 96: 发现更优模型，已保存。
# Epoch 97 训练损失 28.966 	 重构损失 28.964 	 KL 0.002 在步骤 0
# Epoch 97: 发现更优模型，已保存。
# Epoch 98 训练损失 28.967 	 重构损失 28.965 	 KL 0.002 在步骤 0
# Epoch 98: 发现更优模型，已保存。
# Epoch 99 训练损失 28.965 	 重构损失 28.963 	 KL 0.002 在步骤 0
# Epoch 99: 发现更优模型，已保存。

# %%
# ========================== 5. 可视化学习曲线 ========================== #
plt.plot(train_losses, label='Train Loss')
plt.legend()
plt.title('Training loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# ========================== 6. 生成潜在空间样本 ========================== #
model = VAE(input_dim, latent_dim, output_dim).to(device)
model.load_state_dict(torch.load("vae_model.pth", map_location=device))
# 设置为评估模式（禁用 dropout/batch norm 等）
model.eval()

import random
# 随机选择一个批次的数据
# data_iter = iter(test_loader)
# random_batch = next(data_iter)
random_batch = random.choice(list(test_loader))
x_test, _ = random_batch  # 取出输入数据
x_test = x_test.to(device)

# 只取部分特征进行重构
_x_test = x_test[:, :42*2]  # 输入
real_x_test = x_test[:, -42:]  # 真实值

# 进行推理
model.eval()
with torch.no_grad():
    recon_x_test, _, _ = model(_x_test)

# 转换为 NumPy 方便可视化
_x_test_np = _x_test.cpu().numpy()
real_x_test_np = real_x_test.cpu().numpy()
recon_x_test_np = recon_x_test.cpu().numpy()

# 打印部分测试结果
# print("原始输入 (部分特征):", _x_test_np[:5])  # 取前5个样本
# print("真实输出:", real_x_test_np[:5])
# print("重构输出:", recon_x_test_np[:5])

import matplotlib.pyplot as plt

index = random.randint(0, batch_size - 1)

plt.figure(figsize=(10, 5))
plt.plot(real_x_test_np[index], label="ground truth", marker='o')
plt.plot(recon_x_test_np[index], label="VAE recon", marker='x')
plt.legend()
plt.title(f"sample {index} real vs. recon")
plt.xlabel("index")
plt.ylabel("val")
plt.show()
