# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
import pandas as pd

# 自定义数据集类
class SensorDataset(Dataset):
    def __init__(self, data_path):
        data = pd.read_csv(data_path).values
        self.X = data[:, :84].astype(np.float32)   # 输入：前84位
        self.y = data[:, -42:].astype(np.float32)   # 输出：后42位真实数据
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# 自编码器模型
class DenoisingAutoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        # 编码器：84 -> 128 -> 64 -> 32
        self.encoder = nn.Sequential(
            nn.Linear(84, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32)
        )
        # 解码器：32 -> 64 -> 128 -> 42
        self.decoder = nn.Sequential(
            nn.Linear(32, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 42)
        )
    
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# 训练参数设置
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 64
learning_rate = 0.001
num_epochs = 200

# 加载数据集并划分训练集和验证集
dataset = SensorDataset("log.csv")  # 替换为你的数据路径
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# 初始化模型、损失函数和优化器
model = DenoisingAutoencoder().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 训练循环
best_val_loss = float('inf')
for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    train_loss = 0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * inputs.size(0)
    train_loss /= len(train_loader.dataset)
    
    # 验证阶段
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item() * inputs.size(0)
    val_loss /= len(val_dataset)
    
    # 保存最佳模型
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), 'best_model.pth')
    
    print(f'Epoch [{epoch+1}/{num_epochs}] | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}')

# 加载最佳模型进行测试或使用
model.load_state_dict(torch.load('best_model.pth'))
# Out:
# Epoch [1/200] | Train Loss: 0.0708 | Val Loss: 0.0240
# Epoch [2/200] | Train Loss: 0.0559 | Val Loss: 0.0227
# Epoch [3/200] | Train Loss: 0.0541 | Val Loss: 0.0215
# Epoch [4/200] | Train Loss: 0.0526 | Val Loss: 0.0218
# Epoch [5/200] | Train Loss: 0.0514 | Val Loss: 0.0207
# Epoch [6/200] | Train Loss: 0.0506 | Val Loss: 0.0205
# Epoch [7/200] | Train Loss: 0.0497 | Val Loss: 0.0201
# Epoch [8/200] | Train Loss: 0.0488 | Val Loss: 0.0206
# Epoch [9/200] | Train Loss: 0.0482 | Val Loss: 0.0197
# Epoch [10/200] | Train Loss: 0.0473 | Val Loss: 0.0197
# Epoch [11/200] | Train Loss: 0.0467 | Val Loss: 0.0191
# Epoch [12/200] | Train Loss: 0.0462 | Val Loss: 0.0184
# Epoch [13/200] | Train Loss: 0.0457 | Val Loss: 0.0187
# Epoch [14/200] | Train Loss: 0.0454 | Val Loss: 0.0175
# Epoch [15/200] | Train Loss: 0.0448 | Val Loss: 0.0180
# Epoch [16/200] | Train Loss: 0.0446 | Val Loss: 0.0182
# Epoch [17/200] | Train Loss: 0.0444 | Val Loss: 0.0180
# Epoch [18/200] | Train Loss: 0.0441 | Val Loss: 0.0183
# Epoch [19/200] | Train Loss: 0.0439 | Val Loss: 0.0178
# Epoch [20/200] | Train Loss: 0.0437 | Val Loss: 0.0178
# Epoch [21/200] | Train Loss: 0.0436 | Val Loss: 0.0169
# Epoch [22/200] | Train Loss: 0.0435 | Val Loss: 0.0170
# Epoch [23/200] | Train Loss: 0.0434 | Val Loss: 0.0176
# Epoch [24/200] | Train Loss: 0.0433 | Val Loss: 0.0171
# Epoch [25/200] | Train Loss: 0.0433 | Val Loss: 0.0173
# Epoch [26/200] | Train Loss: 0.0433 | Val Loss: 0.0166
# Epoch [27/200] | Train Loss: 0.0430 | Val Loss: 0.0175
# Epoch [28/200] | Train Loss: 0.0432 | Val Loss: 0.0164
# Epoch [29/200] | Train Loss: 0.0430 | Val Loss: 0.0171
# Epoch [30/200] | Train Loss: 0.0429 | Val Loss: 0.0170
# Epoch [31/200] | Train Loss: 0.0430 | Val Loss: 0.0168
# Epoch [32/200] | Train Loss: 0.0429 | Val Loss: 0.0174
# Epoch [33/200] | Train Loss: 0.0429 | Val Loss: 0.0167
# Epoch [34/200] | Train Loss: 0.0428 | Val Loss: 0.0167
# Epoch [175/200] | Train Loss: 0.0418 | Val Loss: 0.0167
# Epoch [176/200] | Train Loss: 0.0419 | Val Loss: 0.0160
# Epoch [177/200] | Train Loss: 0.0418 | Val Loss: 0.0157
# Epoch [178/200] | Train Loss: 0.0419 | Val Loss: 0.0161
# Epoch [179/200] | Train Loss: 0.0418 | Val Loss: 0.0158
# Epoch [180/200] | Train Loss: 0.0419 | Val Loss: 0.0167
# Epoch [181/200] | Train Loss: 0.0418 | Val Loss: 0.0171
# Epoch [182/200] | Train Loss: 0.0418 | Val Loss: 0.0164
# Epoch [183/200] | Train Loss: 0.0418 | Val Loss: 0.0163
# Epoch [184/200] | Train Loss: 0.0418 | Val Loss: 0.0157
# Epoch [185/200] | Train Loss: 0.0419 | Val Loss: 0.0168
# Epoch [186/200] | Train Loss: 0.0419 | Val Loss: 0.0164
# Epoch [187/200] | Train Loss: 0.0418 | Val Loss: 0.0160
# Epoch [188/200] | Train Loss: 0.0418 | Val Loss: 0.0164
# Epoch [189/200] | Train Loss: 0.0419 | Val Loss: 0.0159
# Epoch [190/200] | Train Loss: 0.0419 | Val Loss: 0.0165
# Epoch [191/200] | Train Loss: 0.0418 | Val Loss: 0.0159
# Epoch [192/200] | Train Loss: 0.0418 | Val Loss: 0.0164
# Epoch [193/200] | Train Loss: 0.0419 | Val Loss: 0.0168
# Epoch [194/200] | Train Loss: 0.0419 | Val Loss: 0.0159
# Epoch [195/200] | Train Loss: 0.0419 | Val Loss: 0.0160
# Epoch [196/200] | Train Loss: 0.0418 | Val Loss: 0.0167
# Epoch [197/200] | Train Loss: 0.0418 | Val Loss: 0.0161
# Epoch [198/200] | Train Loss: 0.0418 | Val Loss: 0.0162
# Epoch [199/200] | Train Loss: 0.0418 | Val Loss: 0.0158
# Epoch [200/200] | Train Loss: 0.0418 | Val Loss: 0.0157
# <All keys matched successfully>

# %%
import matplotlib.pyplot as plt
import numpy as np

model = DenoisingAutoencoder().to(device)
model.load_state_dict(torch.load("best_model.pth", map_location=device))
# 设置为评估模式（禁用 dropout/batch norm 等）
model.eval()

import random
# 随机选择一个批次的数据
random_batch = random.choice(list(val_loader))
x_test, _ = random_batch  # 取出输入数据
x_test = x_test.to(device)

# 只取部分特征进行重构
_x_test = x_test[:,  np.r_[:84]]
real_x_test = x_test[:, -42:]#x_test[:, -42:]  # 真实值

# 进行推理
model.eval()
with torch.no_grad():
    recon_x_test = model(_x_test)

# 转换为 NumPy 方便可视化
_x_test_np = _x_test.cpu().numpy()
real_x_test_np = real_x_test.cpu().numpy()
recon_x_test_np = recon_x_test.cpu().numpy()

# 假设 batch_size 和 feature_dim 已知
batch_size = real_x_test_np.shape[0]  # 批次大小
num_features = real_x_test_np.shape[1]  # 特征数量
num_features = 10

# 创建多个子图，每个子图表示一个元素的 real 和 recon 值
fig, axes = plt.subplots(nrows=num_features, figsize=(12, num_features * 3), sharex=True)

# 确保 axes 是一个可迭代的数组
if num_features == 1:
    axes = [axes]

# 遍历每个特征
for i in range(num_features):
    axes[i].plot(np.arange(50), real_x_test_np[:50, i], label="ground truth", marker='o')
    axes[i].plot(np.arange(50), recon_x_test_np[:50, i], label="AE recon", marker='x')
    axes[i].set_title(f"Feature {i} Real vs. Recon")
    axes[i].set_xlabel("Batch Index")
    axes[i].set_ylabel("Value")
    axes[i].legend()

# 调整布局
plt.tight_layout()
plt.show()
